# %%
from tabpfn import TabPFNClassifier

clf = TabPFNClassifier.load_from_fit_state("D:/Projects/Thesis/sem10/pipeline/models/tabpfn_model.tabpfn_fit")
print(clf)
# Out:
# TabPFNClassifier(average_before_softmax=True, balance_probabilities=True,
#                  device='cpu', ignore_pretraining_limits=True, n_estimators=16,
#                  random_state=42, softmax_temperature=0.8)

# %%
clf.__dict__.keys()
# Out:
# dict_keys(['n_estimators', 'categorical_features_indices', 'softmax_temperature', 'balance_probabilities', 'average_before_softmax', 'model_path', 'device', 'ignore_pretraining_limits', 'inference_precision', 'fit_mode', 'memory_saving_mode', 'random_state', 'inference_config', 'differentiable_input', 'n_jobs', 'n_preprocessing_jobs', 'eval_metric', 'tuning_config', 'models_', 'configs_', 'devices_', 'use_autocast_', 'forced_inference_dtype_', 'inference_config_', 'eval_metric_', 'n_features_in_', 'inferred_feature_schema_', 'ordinal_encoder_', 'feature_names_in_', 'n_train_samples_', 'label_encoder_', 'classes_', 'n_classes_', 'class_counts_', 'ensemble_configs_', 'tuned_classification_thresholds_', 'softmax_temperature_', 'ensemble_preprocessor_', 'executor_'])

# %%
print(clf.n_features_in_)
# Out:
# 10

# %%
import numpy as np

X_dummy = np.random.rand(5, clf.n_features_in_)
clf.predict(X_dummy)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 4
#       1 import numpy as np
#       2
#       3 X_dummy = np.random.rand(5, clf.n_features_in_)
# ----> 4 clf.predict(X_dummy)
#
# File d:\Projects\Thesis\sem10\pipeline\thenv\Lib\site-packages\tabpfn_common_utils\telemetry\core\decorators.py:321, in track_model_call.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     319 @functools.wraps(func)
#     320 def wrapper(*args: Any, **kwargs: Any) -> Any:
# --> 321     return _safe_call_with_telemetry(
#     322         func, args, kwargs, model_method, param_names
#     323     )
#
# File d:\Projects\Thesis\sem10\pipeline\thenv\Lib\site-packages\tabpfn_common_utils\telemetry\core\decorators.py:365, in _safe_call_with_telemetry(func, args, kwargs, model_method, param_names)
#     363 # Step 2: Run the actual function
#     364 start = time.perf_counter()
# ...
